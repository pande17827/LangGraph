# %% [markdown]
# <a href="https://colab.research.google.com/github/pande17827/LangGraph/blob/main/3.Reflection%20Agent/1.Reflection%20Agent%20-%20Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b>First of lets try to understand what is Reflection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b>Reflection Agent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b>Reflection Loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
